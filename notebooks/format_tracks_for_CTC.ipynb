# %% [markdown]
# ## Computing CTC Metrics
#
# This Jupyter notebook is designed to evaluate tracking results using the CTC (Cell Tracking Challenge) metrics.
# It loads the predicted cell trajectories and converts them into the required format so they can be processed correctly by the evaluation tools.

# %%
import os
WORK_DIR = os.getcwd()
PATH_OF_SRC_MODUL = WORK_DIR.replace("notebooks", "src")
YOUR_DATA_PATH = r"\\sc-data.sc-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\Fluo-C2DL-Huh7\01"
GRAPH_OUTPUT_PATH = r"\\sc-data.sc-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\Fluo-C2DL-Huh7\01_RES_test"
SAVED_PATHS = "/sc-projects/sc-proj-cc06-agsack/noja11/CellTrack/Training/Dataset/Fluo-N2DH-SIM+/01_RES/calc_paths.npy"
IMAGE_CHANNEL = 1

os.makedirs(GRAPH_OUTPUT_PATH, exist_ok=True)

# %%
import sys
sys.path.append(PATH_OF_SRC_MODUL)
import os
import algo_funcs as algo
import ctc_reformat as ctc
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
import numpy as np
from matplotlib import colors
import scipy
import json
from matplotlib.patches import Rectangle
import cv2
import random

# %%
IMAGE_PATHS_PATTERN = rf'{YOUR_DATA_PATH}/t*.tif'
algo.IMAGE_CHANNEL = IMAGE_CHANNEL

# %%
images = algo.read_images(directory = IMAGE_PATHS_PATTERN, is_gray_scale = True)      
images_unchanged = algo.read_images(directory = IMAGE_PATHS_PATTERN, is_gray_scale = True)

# %%
dict_list = np.load(SAVED_PATHS, allow_pickle=True)

# %%
combined_mask = ctc.save_track_data_to_file(dict_list, n_frames = len(images),output_folder=GRAPH_OUTPUT_PATH)

# %%
from ctc_metrics import evaluate_sequence, validate_sequence
res = validate_sequence(GRAPH_OUTPUT_PATH)
print(res)
# Out:
# {'Valid': 1}c-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\Fluo-N2DH-GOWT1\01_RES_test

# %%
res = evaluate_sequence(GRAPH_OUTPUT_PATH, f"{YOUR_DATA_PATH}_GT")
print("DET: ", res["DET"])
print("TRA: ", res["TRA"])
print("SEG: ", res["SEG"])
# Out:
# Evaluate sequence:  \\sc-data.sc-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\Fluo-C2DL-Huh7\01_RES_test  with ground truth:  \\sc-data.sc-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\Fluo-C2DL-Huh7\01_GTwith results:  {'Valid': 1, 'CHOTA': np.float64(0.8682798377512557), 'BC': None, 'CT': 0.4158415841584158, 'CCA': None, 'TF': np.float64(0.847808105872622), 'SEG': 0.15010595167448398, 'TRA': 0.9295684113865932, 'DET': 0.9443743427970557, 'MOTA': np.float64(0.7581493165089379), 'HOTA': np.float64(0.8626297971079232), 'IDF1': np.float64(0.8260019550342131), 'MTML': None, 'FAF': 7.366666666666666, 'LNK': 0.827536231884058, 'OP_CTB': 0.5398371815305386, 'OP_CSB': 0.5472401472357699, 'BIO': None, 'OP_CLB': None, 'AOGM': np.float64(767.0), 'AOGM_0': np.float64(10890.0), 'AOGM_NS': np.int64(77), 'AOGM_FN': np.int64(0), 'AOGM_FP': np.int64(144), 'AOGM_ED': 0, 'AOGM_EA': np.int64(158), 'AOGM_EC': 1, 'gt_divisions': 1, 'tp_div(0)': 0, 'fp_div(0)': 2, 'fn_div(0)': 1, 'BC(0)': 0.0, 'tp_div(1)': 0, 'fp_div(1)': 2, 'fn_div(1)': 1, 'BC(1)': 0.0, 'tp_div(2)': 0, 'fp_div(2)': 2, 'fn_div(2)': 1, 'BC(2)': 0.0, 'tp_div(3)': 0, 'fp_div(3)': 2, 'fn_div(3)': 1, 'BC(3)': 0.0, 'BIO(0)': np.float64(0.4212165633436793), 'BIO(1)': np.float64(0.4212165633436793), 'BIO(2)': np.float64(0.4212165633436793), 'BIO(3)': np.float64(0.4212165633436793), 'OP_CLB(0)': np.float64(0.6243763976138687), 'OP_CLB(1)': np.float64(0.6243763976138687), 'OP_CLB(2)': np.float64(0.6243763976138687), 'OP_CLB(3)': np.float64(0.6243763976138687), 'TP': 951, 'FP': np.int64(144), 'FN': 0, 'IDSW': np.int64(9), 'MULTI-ASSIGNMENTS': np.int64(77), 'Precision': np.float64(0.8684931506849315), 'Recall': 1.0, 'IDP': np.float64(0.771689497716895), 'IDR': np.float64(0.8885383806519453), 'IDTP': np.float64(845.0), 'IDFP': np.float64(250.0), 'IDFN': np.float64(106.0), 'MT': np.float64(0.8787878787878788), 'ML': np.float64(0.0), 'Frames': 30}  done!
# DET:  0.9443743427970557
# TRA:  0.9295684113865932
# SEG:  0.15010595167448398
