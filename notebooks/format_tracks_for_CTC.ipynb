# %% [markdown]
# ## Computing CTC Metrics
#
# This Jupyter notebook is designed to evaluate tracking results using the CTC (Cell Tracking Challenge) metrics.
# It loads the predicted cell trajectories and converts them into the required format so they can be processed correctly by the evaluation tools.

# %%
import os
WORK_DIR = os.getcwd()
PATH_OF_SRC_MODUL = WORK_DIR.replace("notebooks", "src")
YOUR_DATA_PATH = r"/sc-projects/sc-proj-cc06-agsack/noja11/CellTrack/Training/Dataset/PhC-C2DH-U373/01"
GRAPH_OUTPUT_PATH = "/sc-projects/sc-proj-cc06-agsack/noja11/CellTrack/Training/Dataset/PhC-C2DH-U373/01_RES"
SAVED_PATHS = "/sc-projects/sc-proj-cc06-agsack/noja11/CellTrack/Training/Dataset/PhC-C2DH-U373/01_RES/calc_paths.npy"
IMAGE_CHANNEL = 1

os.makedirs(GRAPH_OUTPUT_PATH, exist_ok=True)

# %%
import sys
sys.path.append(PATH_OF_SRC_MODUL)
import os
import algo_funcs as algo
import ctc_reformat as ctc
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
import numpy as np
from matplotlib import colors
import scipy
import json
from matplotlib.patches import Rectangle
import cv2
import random

# %%
IMAGE_PATHS_PATTERN = rf'{YOUR_DATA_PATH}/t*.tif'
algo.IMAGE_CHANNEL = IMAGE_CHANNEL

# %%
images = algo.read_images(directory = IMAGE_PATHS_PATTERN, is_gray_scale = True)      
images_unchanged = algo.read_images(directory = IMAGE_PATHS_PATTERN, is_gray_scale = True)

# %%
dict_list = np.load(SAVED_PATHS, allow_pickle=True)

# %%
combined_mask = ctc.save_track_data_to_file(dict_list, n_frames = len(images),output_folder=GRAPH_OUTPUT_PATH)
# Out:
# Saved track data to '/sc-projects/sc-proj-cc06-agsack/noja11/CellTrack/Training/Dataset/PhC-C2DH-U373/01_RES'

# %%
from ctc_metrics import evaluate_sequence, validate_sequence
res = validate_sequence(GRAPH_OUTPUT_PATH)
print(res["Valid"])
# Out:
# 1/sc-projects/sc-proj-cc06-agsack/noja11/CellTrack/Training/Dataset/PhC-C2DH-U373/01_RES

# %%
res = evaluate_sequence(GRAPH_OUTPUT_PATH, f"{YOUR_DATA_PATH}_GT")
print("DET: ", res["DET"])
print("TRA: ", res["TRA"])
# Out:
# Evaluate sequence:  /sc-projects/sc-proj-cc06-agsack/noja11/CellTrack/Training/Dataset/PhC-C2DH-U373/01_RES  with ground truth:  /sc-projects/sc-proj-cc06-agsack/noja11/CellTrack/Training/Dataset/PhC-C2DH-U373/01_GTwith results:  {'Valid': 1, 'CHOTA': 0.47341845357358975, 'BC': None, 'CT': 0.0, 'CCA': None, 'TF': 0.3097775175644028, 'SEG': 0.18040318963104476, 'TRA': 0.6126664390576988, 'DET': 0.6129411764705882, 'MOTA': 0.02875816993464053, 'HOTA': 0.47341845357358975, 'IDF1': 0.5636978579481398, 'MTML': None, 'FAF': 4.269565217391304, 'LNK': 0.6108179419525066, 'OP_CTB': 0.39653481434437177, 'OP_CSB': 0.3966721830508165, 'BIO': None, 'OP_CLB': None, 'AOGM': 3403.5, 'AOGM_0': 8787.0, 'AOGM_NS': 0, 'AOGM_FN': 247, 'AOGM_FP': 491, 'AOGM_ED': 0, 'AOGM_EA': 295, 'AOGM_EC': 0, 'BC(0)': None, 'BC(1)': None, 'BC(2)': None, 'BC(3)': None, 'BIO(0)': 0.1548887587822014, 'BIO(1)': 0.1548887587822014, 'BIO(2)': 0.1548887587822014, 'BIO(3)': 0.1548887587822014, 'OP_CLB(0)': 0.382853350367354, 'OP_CLB(1)': 0.382853350367354, 'OP_CLB(2)': 0.382853350367354, 'OP_CLB(3)': 0.382853350367354, 'TP': 518, 'FP': 491, 'FN': 247, 'IDSW': 5, 'MULTI-ASSIGNMENTS': 0, 'Precision': 0.5133795837462835, 'Recall': 0.677124183006536, 'IDP': 0.49554013875123887, 'IDR': 0.6535947712418301, 'IDTP': 500.0, 'IDFP': 509.0, 'IDFN': 265.0, 'MT': 0.14285714285714285, 'ML': 0.0, 'Frames': 115}  done!
# DET:  0.6129411764705882
# SEG:  0.18040318963104476
# TRA:  0.6126664390576988
# CT:  0.0
# TF:  0.3097775175644028
# BC:  None
# CCA:  None
