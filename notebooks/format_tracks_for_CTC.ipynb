# %% [markdown]
# ## Computing CTC Metrics
#
# This Jupyter notebook is designed to evaluate tracking results using the CTC (Cell Tracking Challenge) metrics.
# It loads the predicted cell trajectories and converts them into the required format so they can be processed correctly by the evaluation tools.

# %%
import os
WORK_DIR = os.getcwd()
PATH_OF_SRC_MODUL = WORK_DIR.replace("notebooks", "src")
YOUR_DATA_PATH = r"\\sc-data.sc-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\PhC-C2DH-U373\01"
GRAPH_OUTPUT_PATH = r"\\sc-data.sc-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\PhC-C2DH-U373\01_RES_test"
IMAGE_CHANNEL = 1

os.makedirs(GRAPH_OUTPUT_PATH, exist_ok=True)

# %%
import sys
from ctc_metrics import evaluate_sequence, validate_sequence
sys.path.append(PATH_OF_SRC_MODUL)
res = validate_sequence(GRAPH_OUTPUT_PATH)
print(res)
res = evaluate_sequence(GRAPH_OUTPUT_PATH, f"{YOUR_DATA_PATH}_GT")
print("DET: ", res["DET"])
print("SEG: ", res["SEG"])
print("TRA: ", res["TRA"])
# Out:
# {'Valid': 1}c-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\Fluo-N2DH-SIM+\01_RES_test
# Evaluate sequence:  \\sc-data.sc-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\Fluo-N2DH-SIM+\01_RES_test  with ground truth:  \\sc-data.sc-store.charite.de\sc-project-cc06-agsack\noja11\CellTrack\Training\Dataset\Fluo-N2DH-SIM+\01_GTwith results:  {'Valid': 1, 'CHOTA': np.float64(0.6909509606003601), 'BC': None, 'CT': 0.2397003745318352, 'CCA': 0.0, 'TF': np.float64(0.8467039141300058), 'SEG': 0.7921842424178854, 'TRA': 0.9633769401700834, 'DET': 0.9711929420790181, 'MOTA': np.float64(0.9113924050632911), 'HOTA': np.float64(0.8548095052755175), 'IDF1': np.float64(0.8205424120023082), 'MTML': None, 'FAF': 1.0769230769230769, 'LNK': 0.9105406456631661, 'OP_CTB': 0.8777805912939844, 'OP_CSB': 0.8816885922484518, 'BIO': None, 'OP_CLB': None, 'AOGM': np.float64(1096.0), 'AOGM_0': np.float64(29926.5), 'AOGM_NS': np.int64(30), 'AOGM_FN': np.int64(56), 'AOGM_FP': np.int64(41), 'AOGM_ED': 7, 'AOGM_EA': np.int64(218), 'AOGM_EC': 11, 'gt_divisions': 28, 'tp_div(0)': 2, 'fp_div(0)': 14, 'fn_div(0)': 26, 'BC(0)': 0.09090909090909091, 'tp_div(1)': 3, 'fp_div(1)': 13, 'fn_div(1)': 25, 'BC(1)': 0.13636363636363635, 'tp_div(2)': 3, 'fp_div(2)': 13, 'fn_div(2)': 25, 'BC(2)': 0.13636363636363635, 'tp_div(3)': 3, 'fp_div(3)': 13, 'fn_div(3)': 25, 'BC(3)': 0.13636363636363635, 'BIO(0)': np.float64(0.29432834489273296), 'BIO(1)': np.float64(0.3056919812563693), 'BIO(2)': np.float64(0.3056919812563693), 'BIO(3)': np.float64(0.3056919812563693), 'OP_CLB(0)': np.float64(0.6024344952779495), 'OP_CLB(1)': np.float64(0.6081163134597677), 'OP_CLB(2)': np.float64(0.6081163134597677), 'OP_CLB(3)': np.float64(0.6081163134597677), 'TP': 2551, 'FP': np.int64(41), 'FN': 56, 'IDSW': np.int64(104), 'MULTI-ASSIGNMENTS': np.int64(30), 'Precision': np.float64(0.9841820987654321), 'Recall': 0.9785193709244342, 'IDP': np.float64(0.8229166666666666), 'IDR': np.float64(0.8181818181818182), 'IDTP': np.float64(2133.0), 'IDFP': np.float64(459.0), 'IDFN': np.float64(474.0), 'MT': np.float64(0.7282608695652174), 'ML': np.float64(0.0), 'Frames': 65}  done!
# DET:  0.9711929420790181
# SEG:  0.7921842424178854
# TRA:  0.9633769401700834
